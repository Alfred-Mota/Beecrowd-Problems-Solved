# %% [markdown]
# ### Busca na Internet
#
# Dados do enunciado:
# * ${T_3 = t}$ numero de cliks no terceiro link
# * ${T_2 = 2 * T_3}$ numero de cliks no segundo link com base o terceiro link
# * ${T_2 = \frac{T_1}{2}}$ numero de cliks no segundo link com base o primeiro link
#
# O resultado esperado é o numero de clicks no primeiro link.
#
# Rearranjando os termos dos clicks do segundo link com base no primeiro:
#
# $${T_1 = 2 * T_2}$$
# $${T_1 = 2 * 2 * T_3}$$
# $${T_1 = 4 * t}$$

# %%
import sys
input = sys.stdin.readline
t = int(input())
print(4*t)
